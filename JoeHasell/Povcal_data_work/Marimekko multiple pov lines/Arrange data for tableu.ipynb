# %%
import pandas as pd

# %%
csv_file_url = "https://raw.githubusercontent.com/owid/notebooks/main/JoeHasell/Povcal_data_work/Poverty_and_inequality_measures_from_PovCal_2021.csv"

# %%
df = pd.read_csv('https://raw.githubusercontent.com/owid/notebooks/main/JoeHasell/Povcal_data_work/Poverty_and_inequality_measures_from_PovCal_2021.csv')

# %%
df.head()
# Out:
#     Entity  Year  $1.90 per day - share of population below poverty line  \
# 0  Albania  1981                                           0.464528
# 1  Albania  1982                                           0.407918
# 2  Albania  1983                                           0.464528
# 3  Albania  1984                                           0.534846
# 4  Albania  1985                                           0.534846
#
#    $1.90 per day - poverty gap index  \
# 0                           0.000846
# 1                           0.000816
# 2                           0.000854
# 3                           0.000987
# 4                           0.001000
#
#    $1.90 per day - total number of people below poverty line  \
# 0                                           12663.29
# 1                                           11357.58
# 2                                           13210.98
# 3                                           15534.22
# 4                                           15856.91
#
#    $1.90 per day - absolute poverty gap  \
# 0                              4.622100
# 1                              4.145518
# 2                              4.822009
# 3                              5.669991
# 4                              5.787773
#
#    $3.20 per day - share of population below poverty line  \
# 0                                           7.623522
# 1                                           7.410390
# 2                                           7.623522
# 3                                           8.790304
# 4                                           8.855139
#
#    $3.20 per day - poverty gap index  \
# 0                           0.013227
# 1                           0.012735
# 2                           0.013371
# 3                           0.015602
# 4                           0.015814
#
#    $3.20 per day - total number of people below poverty line  \
# 0                                          207821.48
# 1                                          206325.86
# 2                                          216809.92
# 3                                          255308.14
# 4                                          262533.80
#
#    $3.20 per day - absolute poverty gap  ...  \
# 0                             75.854840  ...
# 1                             75.308938  ...
# 2                             79.135619  ...
# 3                             93.187471  ...
# 4                             95.824836  ...
#
#    Decile 5 – average income or consumption  \
# 0                                  6.082442
# 1                                  6.130848
# 2                                  6.068509
# 3                                  5.867792
# 4                                  5.850741
#
#    Decile 6 – average income or consumption  \
# 0                                  6.790125
# 1                                  6.844163
# 2                                  6.774571
# 3                                  6.550500
# 4                                  6.531465
#
#    Decile 7 – average income or consumption  \
# 0                                  7.853463
# 1                                  7.915964
# 2                                  7.835474
# 3                                  7.576313
# 4                                  7.554298
#
#    Decile 8 – average income or consumption  \
# 0                                  9.051080
# 1                                  9.123112
# 2                                  9.030348
# 3                                  8.731666
# 4                                  8.706293
#
#    Decile 9 – average income or consumption  \
# 0                                 10.814843
# 1                                 10.900912
# 2                                 10.790071
# 3                                 10.433186
# 4                                 10.402868
#
#    Decile 10 – average income or consumption  \
# 0                                  15.402078
# 1                                  15.524654
# 2                                  15.366798
# 3                                  14.858537
# 4                                  14.815360
#
#    $1.00 per day - share of population below poverty line  \
# 0                                           0.057416
# 1                                           0.057416
# 2                                           0.057416
# 3                                           0.057416
# 4                                           0.057416
#
#    $1.00 per day - poverty gap index  \
# 0                           0.000069
# 1                           0.000065
# 2                           0.000071
# 3                           0.000087
# 4                           0.000089
#
#    $1.00 per day - total number of people below poverty line  \
# 0                                            1565.19
# 1                                            1598.62
# 2                                            1632.88
# 3                                            1667.60
# 4                                            1702.24
#
#    $1.00 per day - absolute poverty gap
# 0                              0.571293
# 1                              0.583495
# 2                              0.596002
# 3                              0.608675
# 4                              0.621318
#
# [5 rows x 82 columns]

# %%
df_2017 = df.loc[df.Year == 2017]

# %%
df_2017.head()
# Out:
#                 Entity  Year  \
# 36             Albania  2017
# 75             Algeria  2017
# 114             Angola  2017
# 153  Argentina (Urban)  2017
# 192            Armenia  2017
#
#      $1.90 per day - share of population below poverty line  \
# 36                                            1.266547
# 75                                            0.329316
# 114                                          45.069260
# 153                                           0.928490
# 192                                           0.880793
#
#      $1.90 per day - poverty gap index  \
# 36                            0.001935
# 75                            0.001254
# 114                           0.195752
# 153                           0.002923
# 192                           0.001405
#
#      $1.90 per day - total number of people below poverty line  \
# 36                                            36393.68
# 75                                           136301.21
# 114                                        13438187.68
# 153                                          375209.23
# 192                                           25937.68
#
#      $1.90 per day - absolute poverty gap  \
# 36                              13.283694
# 75                              49.749942
# 114                           4904.938503
# 153                            136.951368
# 192                              9.467252
#
#      $3.20 per day - share of population below poverty line  \
# 36                                            8.189585
# 75                                            2.323713
# 114                                          68.034330
# 153                                           3.181663
# 192                                           8.096853
#
#      $3.20 per day - poverty gap index  \
# 36                            0.017827
# 75                            0.004917
# 114                           0.350932
# 153                           0.009948
# 192                           0.016339
#
#      $3.20 per day - total number of people below poverty line  \
# 36                                           235324.20
# 75                                           961766.17
# 114                                        20285624.73
# 153                                         1285731.46
# 192                                          238436.86
#
#      $3.20 per day - absolute poverty gap  ...  \
# 36                              85.893334  ...
# 75                             351.044654  ...
# 114                           7404.253026  ...
# 153                            469.291984  ...
# 192                             87.029452  ...
#
#      Decile 5 – average income or consumption  \
# 36                                   6.545282
# 75                                   7.500135
# 114                                       NaN
# 153                                 14.480729
# 192                                  5.745936
#
#      Decile 6 – average income or consumption  \
# 36                                   7.666863
# 75                                   8.404083
# 114                                       NaN
# 153                                 17.686371
# 192                                  6.507594
#
#      Decile 7 – average income or consumption  \
# 36                                   9.089712
# 75                                   9.458235
# 114                                       NaN
# 153                                 21.531053
# 192                                  7.401714
#
#      Decile 8 – average income or consumption  \
# 36                                  10.931756
# 75                                  10.832820
# 114                                       NaN
# 153                                 26.668433
# 192                                  8.725566
#
#      Decile 9 – average income or consumption  \
# 36                                  13.746468
# 75                                  13.072209
# 114                                       NaN
# 153                                 34.959245
# 192                                 10.804916
#
#      Decile 10 – average income or consumption  \
# 36                                   21.321229
# 75                                   20.809938
# 114                                        NaN
# 153                                  62.024468
# 192                                  21.848572
#
#      $1.00 per day - share of population below poverty line  \
# 36                                            0.000000
# 75                                            0.090970
# 114                                          20.254290
# 153                                           0.206965
# 192                                           0.024049
#
#      $1.00 per day - poverty gap index  \
# 36                            0.000000
# 75                            0.000729
# 114                           0.069902
# 153                           0.001507
# 192                           0.000021
#
#      $1.00 per day - total number of people below poverty line  \
# 36                                                0.00
# 75                                            37651.93
# 114                                         6039170.61
# 153                                           83635.91
# 192                                             708.18
#
#      $1.00 per day - absolute poverty gap
# 36                               0.000000
# 75                              13.742953
# 114                           2204.297272
# 153                             30.527108
# 192                              0.258487
#
# [5 rows x 82 columns]

# %%
df.Entity.unique().tolist()
# Out:
# ['Albania',
#  'Algeria',
#  'Angola',
#  'Argentina (Urban)',
#  'Armenia',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bangladesh',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'China (Rural)',
#  'China (Urban)',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cyprus',
#  'Czechia',
#  'Democratic Republic of Congo',
#  'Denmark',
#  'Djibouti',
#  'Dominican Republic',
#  'East Asia and Pacific',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Europe and Central Asia',
#  'Fiji',
#  'Finland',
#  'France',
#  'Gabon',
#  'Gambia',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Guinea',
#  'Guinea-Bissau',
#  'Guyana',
#  'Haiti',
#  'Honduras',
#  'Hungary',
#  'Iceland',
#  'India',
#  'India (Rural)',
#  'India (Urban)',
#  'Indonesia',
#  'Indonesia (Rural)',
#  'Indonesia (Urban)',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Japan',
#  'Jordan',
#  'Kazakhstan',
#  'Kenya',
#  'Kiribati',
#  'Kosovo',
#  'Kyrgyzstan',
#  'Laos',
#  'Latin America and the Caribbean',
#  'Latvia',
#  'Lebanon',
#  'Lesotho',
#  'Liberia',
#  'Lithuania',
#  'Luxembourg',
#  'Madagascar',
#  'Malawi',
#  'Malaysia',
#  'Maldives',
#  'Mali',
#  'Malta',
#  'Mauritania',
#  'Mauritius',
#  'Mexico',
#  'Micronesia (country)',
#  'Middle East and North Africa',
#  'Moldova',
#  'Mongolia',
#  'Montenegro',
#  'Morocco',
#  'Mozambique',
#  'Myanmar',
#  'Namibia',
#  'Nauru',
#  'Nepal',
#  'Netherlands',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'North Macedonia',
#  'Norway',
#  'Other high Income (World Bank)',
#  'Pakistan',
#  'Palestine',
#  'Panama',
#  'Papua New Guinea',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Russia',
#  'Rwanda',
#  'Saint Lucia',
#  'Samoa',
#  'Sao Tome and Principe',
#  'Senegal',
#  'Serbia',
#  'Seychelles',
#  'Sierra Leone',
#  'Slovakia',
#  'Slovenia',
#  'Solomon Islands',
#  'Somalia',
#  'South Africa',
#  'South Asia',
#  'South Korea',
#  'South Sudan',
#  'Spain',
#  'Sri Lanka',
#  'Sub-Saharan Africa',
#  'Sudan',
#  'Suriname',
#  'Suriname (Urban)',
#  'Sweden',
#  'Switzerland',
#  'Syria',
#  'Taiwan',
#  'Tajikistan',
#  'Tanzania',
#  'Thailand',
#  'Timor',
#  'Togo',
#  'Tonga',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkey',
#  'Turkmenistan',
#  'Tuvalu',
#  'Uganda',
#  'Ukraine',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Uzbekistan',
#  'Vanuatu',
#  'Venezuela',
#  'Vietnam',
#  'World',
#  'Yemen',
#  'Zambia',
#  'Zimbabwe']

# %%
exclude_list = ['China (Rural)','China (Urban)','East Asia and Pacific','Europe and Central Asia','India (Rural)','India (Urban)','Indonesia (Rural)','Indonesia (Urban)','Latin America and the Caribbean','Middle East and North Africa','Other high Income (World Bank)','South Asia','Sub-Saharan Africa','Suriname (Urban)','World']

# %%
df_2017_countries = df_2017[~df_2017["Entity"].isin(exclude_list)]

# %%
df_2017_countries.head()
# Out:
#                 Entity  Year  \
# 36             Albania  2017
# 75             Algeria  2017
# 114             Angola  2017
# 153  Argentina (Urban)  2017
# 192            Armenia  2017
#
#      $1.90 per day - share of population below poverty line  \
# 36                                            1.266547
# 75                                            0.329316
# 114                                          45.069260
# 153                                           0.928490
# 192                                           0.880793
#
#      $1.90 per day - poverty gap index  \
# 36                            0.001935
# 75                            0.001254
# 114                           0.195752
# 153                           0.002923
# 192                           0.001405
#
#      $1.90 per day - total number of people below poverty line  \
# 36                                            36393.68
# 75                                           136301.21
# 114                                        13438187.68
# 153                                          375209.23
# 192                                           25937.68
#
#      $1.90 per day - absolute poverty gap  \
# 36                              13.283694
# 75                              49.749942
# 114                           4904.938503
# 153                            136.951368
# 192                              9.467252
#
#      $3.20 per day - share of population below poverty line  \
# 36                                            8.189585
# 75                                            2.323713
# 114                                          68.034330
# 153                                           3.181663
# 192                                           8.096853
#
#      $3.20 per day - poverty gap index  \
# 36                            0.017827
# 75                            0.004917
# 114                           0.350932
# 153                           0.009948
# 192                           0.016339
#
#      $3.20 per day - total number of people below poverty line  \
# 36                                           235324.20
# 75                                           961766.17
# 114                                        20285624.73
# 153                                         1285731.46
# 192                                          238436.86
#
#      $3.20 per day - absolute poverty gap  ...  \
# 36                              85.893334  ...
# 75                             351.044654  ...
# 114                           7404.253026  ...
# 153                            469.291984  ...
# 192                             87.029452  ...
#
#      Decile 5 – average income or consumption  \
# 36                                   6.545282
# 75                                   7.500135
# 114                                       NaN
# 153                                 14.480729
# 192                                  5.745936
#
#      Decile 6 – average income or consumption  \
# 36                                   7.666863
# 75                                   8.404083
# 114                                       NaN
# 153                                 17.686371
# 192                                  6.507594
#
#      Decile 7 – average income or consumption  \
# 36                                   9.089712
# 75                                   9.458235
# 114                                       NaN
# 153                                 21.531053
# 192                                  7.401714
#
#      Decile 8 – average income or consumption  \
# 36                                  10.931756
# 75                                  10.832820
# 114                                       NaN
# 153                                 26.668433
# 192                                  8.725566
#
#      Decile 9 – average income or consumption  \
# 36                                  13.746468
# 75                                  13.072209
# 114                                       NaN
# 153                                 34.959245
# 192                                 10.804916
#
#      Decile 10 – average income or consumption  \
# 36                                   21.321229
# 75                                   20.809938
# 114                                        NaN
# 153                                  62.024468
# 192                                  21.848572
#
#      $1.00 per day - share of population below poverty line  \
# 36                                            0.000000
# 75                                            0.090970
# 114                                          20.254290
# 153                                           0.206965
# 192                                           0.024049
#
#      $1.00 per day - poverty gap index  \
# 36                            0.000000
# 75                            0.000729
# 114                           0.069902
# 153                           0.001507
# 192                           0.000021
#
#      $1.00 per day - total number of people below poverty line  \
# 36                                                0.00
# 75                                            37651.93
# 114                                         6039170.61
# 153                                           83635.91
# 192                                             708.18
#
#      $1.00 per day - absolute poverty gap
# 36                               0.000000
# 75                              13.742953
# 114                           2204.297272
# 153                             30.527108
# 192                              0.258487
#
# [5 rows x 82 columns]

# %%
df_2017_countries["threshold Above $30 per day"] = df_2017_countries["Population"] - df_2017_countries["$30.00 per day - total number of people below poverty line"]
# Out:
# /var/folders/x7/v_yg2r8j0q19373df27vt6nm0000gp/T/ipykernel_81963/2903881341.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017_countries["threshold Above $30 per day"] = df_2017_countries["Population"] - df_2017_countries["$30.00 per day - total number of people below poverty line"]

# %%
df_2017_countries["threshold $10 - $30 per day"] = df_2017_countries["$30.00 per day - total number of people below poverty line"] - df_2017_countries["$10.00 per day - total number of people below poverty line"]
# Out:
# /var/folders/x7/v_yg2r8j0q19373df27vt6nm0000gp/T/ipykernel_81963/3912326866.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017_countries["threshold $10 - $30 per day"] = df_2017_countries["$30.00 per day - total number of people below poverty line"] - df_2017_countries["$10.00 per day - total number of people below poverty line"]

# %%
df_2017_countries["threshold $1.90 - $10 per day"] = df_2017_countries["$10.00 per day - total number of people below poverty line"] - df_2017_countries["$1.90 per day - total number of people below poverty line"]
# Out:
# /var/folders/x7/v_yg2r8j0q19373df27vt6nm0000gp/T/ipykernel_81963/1327207698.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017_countries["threshold $1.90 - $10 per day"] = df_2017_countries["$10.00 per day - total number of people below poverty line"] - df_2017_countries["$1.90 per day - total number of people below poverty line"]

# %%
df_2017_countries["threshold below $1.90 per day"] = df_2017_countries["$1.90 per day - total number of people below poverty line"]
# Out:
# /var/folders/x7/v_yg2r8j0q19373df27vt6nm0000gp/T/ipykernel_81963/2142158082.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2017_countries["threshold below $1.90 per day"] = df_2017_countries["$1.90 per day - total number of people below poverty line"]

# %%
df_2017_countries = df_2017_countries[['Entity', 'threshold below $1.90 per day', \
                                     "threshold $1.90 - $10 per day", "threshold $10 - $30 per day", "threshold Above $30 per day" ]]

# %%
df_2017_countries.head()
# Out:
#                 Entity  threshold below $1.90 per day  \
# 36             Albania                       36393.68
# 75             Algeria                      136301.21
# 114             Angola                    13438187.68
# 153  Argentina (Urban)                      375209.23
# 192            Armenia                       25937.68
#
#      threshold $1.90 - $10 per day  threshold $10 - $30 per day  \
# 36                      1990457.55                    824128.15
# 75                     28416471.62                  12431998.90
# 114                    15246999.83                   1022416.28
# 153                    11030731.79                  20856373.17
# 192                     2390126.74                    493307.93
#
#      threshold Above $30 per day
# 36                      22477.62
# 75                     404426.27
# 114                    109144.21
# 153                   8148359.81
# 192                     35436.65

# %%
df2 = pd.melt(df_2017_countries,id_vars=['Entity'],var_name='metric', value_name='value')
df2.head(n=600)
# Out:
#                    Entity                         metric        value
# 0                 Albania  threshold below $1.90 per day     36393.68
# 1                 Algeria  threshold below $1.90 per day    136301.21
# 2                  Angola  threshold below $1.90 per day  13438187.68
# 3       Argentina (Urban)  threshold below $1.90 per day    375209.23
# 4                 Armenia  threshold below $1.90 per day     25937.68
# ..                    ...                            ...          ...
# 595  Micronesia (country)    threshold Above $30 per day       455.86
# 596               Moldova    threshold Above $30 per day     18532.85
# 597              Mongolia    threshold Above $30 per day     40738.50
# 598            Montenegro    threshold Above $30 per day     59906.95
# 599               Morocco    threshold Above $30 per day   1544573.30
#
# [600 rows x 3 columns]

# %%
df2.to_csv("povcal_number_at_different_thresholds_2007.csv")
