# %%
import pandas as pd
import requests, zipfile, io
from zipfile import ZipFile

# %% [markdown]
# Load in the main UCDP georeferenced data (1989-2020)

# %%
xy_file = ZipFile("data/input/ged221-csv.zip")

df = pd.read_csv(xy_file.open('GEDEvent_v22_1.csv'))

df.tail()
# Out:
# /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            id               relid  year  active_year code_status  \
# 293629  15525   MZM-1989-3-1347-4  1989            1       Clear
# 293630  15524  MZM-1989-3-1347-16  1989            1       Clear
# 293631  15245  MZM-1990-3-1347-18  1990            1       Clear
# 293632  15516  MZM-1990-3-1347-28  1990            1       Clear
# 293633  15493  MZM-1990-3-1347-29  1990            1       Clear
#
#         type_of_violence  conflict_dset_id  conflict_new_id  \
# 293629                 3               498              562
# 293630                 3               498              562
# 293631                 3               498              562
# 293632                 3               498              562
# 293633                 3               498              562
#
#              conflict_name  dyad_dset_id  ...                 date_end  \
# 293629  Renamo - Civilians           498  ...  1989-03-24 00:00:00.000
# 293630  Renamo - Civilians           498  ...  1989-07-15 00:00:00.000
# 293631  Renamo - Civilians           498  ...  1990-06-10 00:00:00.000
# 293632  Renamo - Civilians           498  ...  1990-11-23 00:00:00.000
# 293633  Renamo - Civilians           498  ...  1990-11-25 00:00:00.000
#
#        deaths_a  deaths_b  deaths_civilians deaths_unknown  best  high low  \
# 293629        0         0                 9              0     9     9   9
# 293630        0         0                 9              0     9     9   9
# 293631        0         0                 7              0     7     7   7
# 293632        0         0                 1              0     1     1   1
# 293633        0         0                 6              0     6     6   6
#
#         gwnoa gwnob
# 293629    NaN   NaN
# 293630    NaN   NaN
# 293631    NaN   NaN
# 293632    NaN   NaN
# 293633    NaN   NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# ### Sense check

# %% [markdown]
# Note that `id` is unique.

# %%
df[df[['id']].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, relid, year, active_year, code_status, type_of_violence, conflict_dset_id, conflict_new_id, conflict_name, dyad_dset_id, dyad_new_id, dyad_name, side_a_dset_id, side_a_new_id, side_a, side_b_dset_id, side_b_new_id, side_b, number_of_sources, source_article, source_office, source_date, source_headline, source_original, where_prec, where_coordinates, where_description, adm_1, adm_2, latitude, longitude, geom_wkt, priogrid_gid, country, country_id, region, event_clarity, date_prec, date_start, date_end, deaths_a, deaths_b, deaths_civilians, deaths_unknown, best, high, low, gwnoa, gwnob]
# Index: []
#
# [0 rows x 49 columns]

# %% [markdown]
# Note that `relid` is unique.

# %%
df[df[['relid']].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, relid, year, active_year, code_status, type_of_violence, conflict_dset_id, conflict_new_id, conflict_name, dyad_dset_id, dyad_new_id, dyad_name, side_a_dset_id, side_a_new_id, side_a, side_b_dset_id, side_b_new_id, side_b, number_of_sources, source_article, source_office, source_date, source_headline, source_original, where_prec, where_coordinates, where_description, adm_1, adm_2, latitude, longitude, geom_wkt, priogrid_gid, country, country_id, region, event_clarity, date_prec, date_start, date_end, deaths_a, deaths_b, deaths_civilians, deaths_unknown, best, high, low, gwnoa, gwnob]
# Index: []
#
# [0 rows x 49 columns]

# %% [markdown]
# Note that there are some rows where the deaths estimates dont make sense.

# %% [markdown]
# ... where the `high` estimate is lower than the `low` estimate:

# %%
df[df['high']<df['low']].head()
# Out:
#           id                 relid  year  active_year code_status  \
# 89    134354    AFG-1990-1-412-3.1  1990            1       Clear
# 206   145886     AFG-1993-1-412-52  1993            1       Clear
# 277   146345   AFG-1995-1-412-13.1  1995            1       Clear
# 527   186176   AFG-1989-1-413-1000  1989            1       Clear
# 4077  133321  AFG-2008-1-327-361.1  2008            1       Clear
#
#       type_of_violence  conflict_dset_id  conflict_new_id  \
# 89                   1               333              333
# 206                  1               333              333
# 277                  1               333              333
# 527                  1               333              333
# 4077                 1               333              333
#
#                 conflict_name  dyad_dset_id  ...                 date_end  \
# 89    Afghanistan: Government           726  ...  1990-10-12 00:00:00.000
# 206   Afghanistan: Government           726  ...  1993-10-14 00:00:00.000
# 277   Afghanistan: Government           726  ...  1995-08-22 00:00:00.000
# 527   Afghanistan: Government           732  ...  1989-12-31 00:00:00.000
# 4077  Afghanistan: Government           735  ...  2008-07-17 00:00:00.000
#
#      deaths_a  deaths_b  deaths_civilians deaths_unknown  best  high  low  \
# 89          0        36                 0            100   136   135  136
# 206         0         0                 0             53    53    33   53
# 277         0         2                 0              0     2     1    2
# 527         0         0                 0             21    21     0   21
# 4077        0         8                 0              0     8     7    8
#
#       gwnoa gwnob
# 89      700   NaN
# 206     700   NaN
# 277     700   NaN
# 527     700   NaN
# 4077    700   NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# I make an amended set of deaths data, where `high` estimates are swapped for `low` where `high`<`low`.

# %%
df['high_amend'] = df['high']

# %%
df.loc[(df.high<df.low), 'high_amend'] = df.loc[(df.high<df.low), 'low']

# %%
df['low_amend'] = df['low']

# %%
df.loc[(df.high<df.low), 'low_amend'] = df.loc[(df.high<df.low), 'high']

# %% [markdown]
# There are also rows where the `best` estimate falls outside the `low`-`high` range.

# %%
df[(df['best']<df['low_amend']) | (df['best']>df['high_amend'])].head()
# Out:
#            id                  relid  year  active_year code_status  \
# 437    133990    AFG-1989-1-760-41.1  1989            1       Clear
# 458    134076    AFG-1989-1-760-57.3  1989            1       Clear
# 7696   168597  AFG-2010-1-327-2484.1  2010            1       Clear
# 9791   186137  AFG-2011-1-327-3078.3  2011            1       Clear
# 14967  163028  AFG-2014-1-327-1655.2  2014            1       Clear
#
#        type_of_violence  conflict_dset_id  conflict_new_id  \
# 437                   1               333              333
# 458                   1               333              333
# 7696                  1               333              333
# 9791                  1               333              333
# 14967                 1               333              333
#
#                  conflict_name  dyad_dset_id  ...  deaths_b deaths_civilians  \
# 437    Afghanistan: Government           727  ...        18                3
# 458    Afghanistan: Government           727  ...         0                0
# 7696   Afghanistan: Government           735  ...         3                0
# 9791   Afghanistan: Government           735  ...         3                0
# 14967  Afghanistan: Government           735  ...         1                0
#
#        deaths_unknown  best high  low  gwnoa gwnob  high_amend low_amend
# 437                 0    22   21    0    700   NaN          21         0
# 458                78    85   84    0    700   NaN          84         0
# 7696                0     3    2    2    700   NaN           2         2
# 9791                0     3    4    4    700   NaN           4         4
# 14967               0     4   11    5    700   NaN          11         5
#
# [5 rows x 51 columns]

# %% [markdown]
# I extend the (amended) `high` or `low` values to include the `best` estimate.

# %%
df.loc[(df.best<df.low_amend), 'low_amend'] = df.loc[(df.best<df.low_amend), 'best']

# %%
df.loc[(df.best>df.high_amend), 'high_amend'] = df.loc[(df.best>df.high_amend), 'best']

# %% [markdown]
# ### Output as csv

# %%
df.to_csv('data/manipulation/tidied_geolocated_data.csv.gz', index = False, compression = "gzip")
