# %% [markdown]
# # ODA data by Sector (with donor and recipient)
# This tutorial shows you how to build a Pandas DataFrame containing ODA data from any number of donors to any number of recipients, across sectors available in the list of indicators, over a range of years.
#
# The tutorial has the following steps:
# 1. Import `ODAData`, the main tool used to interact with the data
# 2. Create an instance of `ODAData` with the specific arguments you would like to use
# 3. Load the indicators and get the DataFrame
# 4. Optionally, export the DataFrame

# %% [markdown]
# ## 1. Import ODAData
#
# We can gather the data we need using the `ODAData` class. An object from this class can:
#     - Get data for specific indicators
#     - Optionally, filter the data for specific donors, recipients and years
#     - Optionally, exchange and deflate data
#
# The `oda_data` package automatically downloads the relevant datasets (i.e. DAC1, DAC2a or CRS tables) depending on the indicators selected in step 3.
#
# It is highly recommended that you specify the folder where you want to store, and from where you want to read, this raw data. This must be done once in each notebook or script where we use the `oda_data` package. You can specify the data path if the raw data has already been downloaded, or if you haven't yet specified the download path in your notebook and script.

# %%
from oda_data import ODAData, set_data_path

# in section 3, we give the option to retreive data for specific donor and recipient groupings, so we need to import the following
from oda_data.tools.groupings import donor_groupings, recipient_groupings

# If you haven't set the data path, you can do it now.
set_data_path(path="/Users/parriagadap/notebooks/PabloArriagada/oda_data")
# Out:
# /Users/parriagadap/etl/.venv/lib/python3.11/site-packages/pypdf/_crypt_providers/_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from this module in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4

# %% [markdown]
# # 2. Create an instance of ODAData
#
# Next, we need to set the right arguments which are used to create an instance of ODAData to produce the right DataFrame. The arguments required are:
# - *years*: you must specify the `years`, as an `int`, `list` or `range`
# - *donors*: you can _optionally_ specify the `donors` you want the output to have (as `int`, or `list`) of donor codes.
# - *recipients*: you can _optionally_ specify the `recipients` you want the output to have. Not all indicators
#     need or accept recipients. If using an indicator for which recipients are not an option, a warning will be logged to
#     the console and the recipients ignored for that indicator.
# - *currency*: you can _optionally_ specify the `currency` in which you want your data to be shown. If not specified,
#     by default, `USD` will be used. Other options include `EUR`, `GBP` and `CAN`.
# - *prices*: you can _optionally_ specify the `prices` in which you want your data to be shown. If not specified,
#     by default, `current` will be used. The other option is `constant`. If specifying `constant` a `base_year` must be set.
# - *base_year*: you must specify a `base_year` if you have set `prices = 'constant'`. If you have chosen `current` prices,
#     by default, `base_year` will be `None`.

# %% [markdown]
# You can use a few methods provided by the ODAData object to see the available donors, recipients and donor/recipient groupings.

# %%
# print a list of available donors
ODAData().available_donors()
# Out:
# INFO 2024-09-16 16:56:25,702 [oda_data.py:available_donors:469] Note that not all donors may be available for all indicators
# INFO: Note that not all donors may be available for all indicators
# {
# 1: Austria,
# 2: Belgium,
# 3: Denmark,
# 4: France,
# 5: Germany,
# 6: Italy,
# 7: Netherlands,
# 8: Norway,
# 9: Portugal,
# 10: Sweden,
# 11: Switzerland,
# 12: United Kingdom,
# 18: Finland,
# 20: Iceland,
# 21: Ireland,
# 22: Luxembourg,
# 40: Greece,
# 50: Spain,
# 61: Slovenia,
# 68: Czech Republic,
# 69: Slovak Republic,
# 75: Hungary,
# 76: Poland,
# 301: Canada,
# 302: United States,
# 701: Japan,
# 742: Korea,
# 801: Australia,
# 820: New Zealand,
# 30: Cyprus,
# 45: Malta,
# 55: Turkey,
# 62: Croatia,
# 70: Liechtenstein,
# 72: Bulgaria,
# 77: Romania,
# 82: Estonia,
# 83: Latvia,
# 84: Lithuania,
# 87: Russia,
# 130: Algeria,
# 133: Libya,
# 358: Mexico,
# 543: Iraq,
# 546: Israel,
# 552: Kuwait,
# 561: Qatar,
# 566: Saudi Arabia,
# 576: United Arab Emirates,
# 611: Azerbaijan,
# 613: Kazakhstan,
# 732: Chinese Taipei,
# 764: Thailand,
# 765: Timor-Leste,
# 104: Nordic Development Fund,
# 807: UNEP,
# 811: Global Environment Facility,
# 812: Montreal Protocol,
# 901: International Bank for Reconstruction and Development,
# 902: Multilateral Investment Guarantee Agency,
# 903: International Finance Corporation,
# 905: International Development Association,
# 906: Caribbean Development Bank,
# 907: International Monetary Fund,
# 909: Inter-American Development Bank,
# 913: African Development Bank,
# 914: African Development Fund,
# 915: Asian Development Bank,
# 921: Arab Fund (AFESD),
# 923: UN Peacebuilding Fund,
# 926: Council of Europe,
# 928: World Health Organisation,
# 932: Food and Agriculture Organisation,
# 940: International Labour Organisation,
# 944: International Atomic Energy Agency,
# 948: UNECE,
# 951: OPEC Fund for International Development,
# 952: OAPEC,
# 953: Arab Bank for Economic Development in Africa,
# 954: Special Arab Aid Fund for Africa,
# 956: IMF Trust Fund,
# 958: IMF (Concessional Trust Funds),
# 959: UNDP,
# 960: UNTA,
# 963: UNICEF,
# 964: UNRWA,
# 966: WFP,
# 967: UNHCR,
# 971: UNAIDS,
# 974: UNFPA,
# 976: Islamic Development Bank,
# 978: OSCE,
# 979: Islamic Monetary Fund,
# 980: Arab Fund for Technical Assistance to African and Arab Countries,
# 981: Black Sea Trade & Development Bank,
# 982: GODE,
# 983: Other Arab Agencies,
# 988: IFAD,
# 990: European Bank for Reconstruction and Development,
# 992: UN AGENCIES,
# 997: Global Partnership for Education,
# 1011: Climate Investment Funds,
# 1012: Adaptation Fund,
# 1013: Council of Europe Development Bank,
# 1014: Private Infrastructure Development Group,
# 1015: Development Bank of Latin America,
# 1016: Green Climate Fund,
# 1017: Credit Guarantee and Investment Facility,
# 1018: Global Energy Efficiency and Renewable Energy Fund,
# 1019: IDB Invest,
# 1020: Central Emergency Response Fund,
# 1023: World Tourism Organisation,
# 1024: Asian Infrastructure Investment Bank,
# 1025: Center of Excellence in Finance,
# 1037: International Investment Bank,
# 1311: Global Alliance for Vaccines and Immunization,
# 1312: Global Fund,
# 1313: Global Green Growth Institute,
# 918: EU Institutions,
# 20001: DAC Countries, Total,
# 20002: Multilaterals, Total,
# 20003: G7 Countries, Total,
# 20005: Official Donors, Total,
# 20006: Non-DAC Countries, Total,
# 20012: World Bank Group, Total,
# 20013: International Monetary Fund, Total,
# 20014: Inter-American Development Bank, Total,
# 20015: Asian Development Bank, Total,
# 20016: African Development Bank, Total,
# 20021: United Nations, Total,
# 20022: Regional Development Banks, Total,
# 20033: World Bank, Total,
# 20034: Other Multilateral, Total,
# 20035: United Postcode Lotteries, Total,
# 21600: Private Donors, Total
# }

# %%
# print a list of available recipients
ODAData().available_recipients()
# Out:
# INFO 2024-09-16 16:56:25,708 [oda_data.py:available_recipients:475] Note that not all recipients may be available for all indicators
# INFO: Note that not all recipients may be available for all indicators
# {
# 30: Cyprus,
# 35: Gibraltar,
# 45: Malta,
# 55: Turkey,
# 57: Kosovo,
# 61: Slovenia,
# 62: Croatia,
# 63: Serbia,
# 64: Bosnia and Herzegovina,
# 65: Montenegro,
# 66: North Macedonia,
# 71: Albania,
# 85: Ukraine,
# 86: Belarus,
# 88: States Ex-Yugoslavia unspecified,
# 89: Europe, regional,
# 93: Moldova,
# 130: Algeria,
# 133: Libya,
# 136: Morocco,
# 139: Tunisia,
# 142: Egypt,
# 189: North of Sahara, regional,
# 218: South Africa,
# 225: Angola,
# 227: Botswana,
# 228: Burundi,
# 229: Cameroon,
# 230: Cabo Verde,
# 231: Central African Republic,
# 232: Chad,
# 233: Comoros,
# 234: Congo,
# 235: Democratic Republic of the Congo,
# 236: Benin,
# 237: East African Community,
# 238: Ethiopia,
# 239: Gabon,
# 240: Gambia,
# 241: Ghana,
# 243: Guinea,
# 244: Guinea-Bissau,
# 245: Equatorial Guinea,
# 247: Cote d'Ivoire,
# 248: Kenya,
# 249: Lesotho,
# 251: Liberia,
# 252: Madagascar,
# 253: Malawi,
# 255: Mali,
# 256: Mauritania,
# 257: Mauritius,
# 258: Mayotte,
# 259: Mozambique,
# 260: Niger,
# 261: Nigeria,
# 265: Zimbabwe,
# 266: Rwanda,
# 268: Sao Tome and Principe,
# 269: Senegal,
# 270: Seychelles,
# 271: Eritrea,
# 272: Sierra Leone,
# 273: Somalia,
# 274: Djibouti,
# 275: Namibia,
# 276: Saint Helena,
# 278: Sudan,
# 279: South Sudan,
# 280: Eswatini,
# 282: Tanzania,
# 283: Togo,
# 285: Uganda,
# 287: Burkina Faso,
# 288: Zambia,
# 289: South of Sahara, regional,
# 298: Africa, regional,
# 328: Bahamas,
# 329: Barbados,
# 331: Bermuda,
# 336: Costa Rica,
# 338: Cuba,
# 340: Dominican Republic,
# 342: El Salvador,
# 347: Guatemala,
# 349: Haiti,
# 351: Honduras,
# 352: Belize,
# 354: Jamaica,
# 358: Mexico,
# 361: Netherlands Antilles,
# 364: Nicaragua,
# 366: Panama,
# 373: Aruba,
# 375: Trinidad and Tobago,
# 376: Anguilla,
# 377: Antigua and Barbuda,
# 378: Dominica,
# 381: Grenada,
# 382: Saint Kitts and Nevis,
# 383: Saint Lucia,
# 384: Saint Vincent and the Grenadines,
# 385: Montserrat,
# 386: Cayman Islands,
# 387: Turks and Caicos Islands,
# 388: British Virgin Islands,
# 389: Caribbean & Central America, regional,
# 425: Argentina,
# 428: Bolivia,
# 431: Brazil,
# 434: Chile,
# 437: Colombia,
# 440: Ecuador,
# 446: Guyana,
# 451: Paraguay,
# 454: Peru,
# 457: Suriname,
# 460: Uruguay,
# 463: Venezuela,
# 489: South America, regional,
# 498: America, regional,
# 530: Bahrain,
# 540: Iran,
# 543: Iraq,
# 546: Israel,
# 549: Jordan,
# 550: West Bank and Gaza Strip,
# 552: Kuwait,
# 555: Lebanon,
# 558: Oman,
# 561: Qatar,
# 566: Saudi Arabia,
# 573: Syrian Arab Republic,
# 576: United Arab Emirates,
# 580: Yemen,
# 589: Middle East, regional,
# 610: Armenia,
# 611: Azerbaijan,
# 612: Georgia,
# 613: Kazakhstan,
# 614: Kyrgyzstan,
# 615: Tajikistan,
# 616: Turkmenistan,
# 617: Uzbekistan,
# 619: Central Asia, regional,
# 625: Afghanistan,
# 630: Bhutan,
# 635: Myanmar,
# 640: Sri Lanka,
# 645: India,
# 650: Indus Basin,
# 655: Maldives,
# 660: Nepal,
# 665: Pakistan,
# 666: Bangladesh,
# 679: South Asia, regional,
# 689: South & Central Asia, regional,
# 725: Brunei Darussalam,
# 728: Cambodia,
# 730: China (People's Republic of),
# 732: Chinese Taipei,
# 735: Hong Kong (China),
# 738: Indonesia,
# 740: Democratic People's Republic of Korea,
# 742: Korea,
# 745: Lao People's Democratic Republic,
# 748: Macau (China),
# 751: Malaysia,
# 753: Mongolia,
# 755: Philippines,
# 761: Singapore,
# 764: Thailand,
# 765: Timor-Leste,
# 769: Viet Nam,
# 789: Far East Asia, regional,
# 798: Asia, regional,
# 816: Other Regional Banks,
# 831: Cook Islands,
# 832: Fiji,
# 836: Kiribati,
# 840: French Polynesia,
# 845: Nauru,
# 850: New Caledonia,
# 854: Vanuatu,
# 856: Niue,
# 858: Northern Mariana Islands,
# 859: Marshall Islands,
# 860: Micronesia,
# 861: Palau,
# 862: Papua New Guinea,
# 866: Solomon Islands,
# 868: Tokelau,
# 870: Tonga,
# 872: Tuvalu,
# 876: Wallis and Futuna,
# 880: Samoa,
# 889: Oceania, regional,
# 900: Other World Bank (AMCs),
# 901: IBRD,
# 902: MIGA,
# 903: IFC,
# 904: IDA-MDRI,
# 905: IDA,
# 906: Caribbean Dev. Bank,
# 907: IMF,
# 909: IDB,
# 910: CABEI,
# 912: IDB Special Oper. Fund,
# 913: Af. D B,
# 914: African Dev. Fund,
# 915: Asian Dev. Bank,
# 916: AsDB Special Funds,
# 917: EC,
# 918: EDF,
# 919: EIB,
# 927: Other EU institutions,
# 959: UNDP,
# 963: UNICEF,
# 964: UNRWA,
# 966: WFP,
# 967: UNHCR,
# 974: UNFPA,
# 975: Other UN,
# 988: IFAD,
# 989: Other Multilateral,
# 1031: Caribbean, regional,
# 9998: Developing countries, unspecified,
# 10001: Africa, Total,
# 10002: North of Sahara, Total,
# 10003: South of Sahara, Total,
# 10004: America, Total,
# 10005: Caribbean & Central America, Total,
# 10006: South America, Total,
# 10007: Asia, Total,
# 10008: Far East Asia, Total,
# 10009: South & Central Asia, Total,
# 10010: Europe, Total,
# 10011: Middle East, Total,
# 10012: Oceania, Total,
# 10013: CEEC, Total,
# 10014: NIS, Total,
# 10016: LDCs, Total,
# 10017: Other LICs, Total,
# 10018: LMICs, Total,
# 10019: UMICs, Total,
# 10024: Part I Unallocated by income,
# 10025: MADCTs, Total,
# 10026: Part II Countries, Total,
# 10030: HIPCs, Total,
# 10040: ACP Countries, Total,
# 10041: Club du Sahel, Total,
# 10045: WorldBank Low income countries,
# 10046: WorldBank Lower-middle income countries,
# 10047: WorldBank Upper-middle income countries,
# 10048: WorldBank High income countries,
# 10049: Countries not classified by the World Bank,
# 10050: Eastern Africa, Total,
# 10051: Middle Africa, Total,
# 10052: Southern Africa, Total,
# 10053: Western Africa, Total,
# 10054: Caribbean, Total,
# 10055: Central America, Total,
# 10056: Northern America, Total,
# 10057: Melanesia, Total,
# 10058: Micronesia, Total,
# 10059: Polynesia, Total,
# 10100: Developing Countries, Total,
# 10150: All Multilateral Recipients, Total,
# 10200: All Recipients, Total,
# 10201: Land-Locked countries, Total,
# 10202: Small island states, Total,
# 10203: Fragile states, Total,
# 1027: Eastern Africa, regional,
# 1030: Western Africa, regional,
# 1028: Middle Africa, regional,
# 1029: Southern Africa, regional,
# 1032: Central America, regional,
# 1033: Melanesia, regional,
# 1034: Micronesia, regional
# }

# %%
# Print available donor groupings
print(donor_groupings().keys())
# Out:
# dict_keys(['dac_members', 'dac_countries', 'non_dac_countries', 'multilateral', 'all_bilateral', 'all_official', 'g7', 'eu27_total', 'eu27_countries', 'dac1_aggregates'])

# %%
# Print available recipient groupings
print(recipient_groupings().keys())
# Out:
# dict_keys(['all_recipients', 'all_developing_countries_regions', 'african_countries', 'africa_regional', 'african_countries_regional', 'sahel', 'ldc_countries', 'france_priority', 'dac2a_aggregates'])

# %% [markdown]
# Next, in order to get the data we want, we will create an instance of the `ODAData` class by specifying the correct arguments.
#
# We will store this instance in a variable called `oda`, which we will use later to load the indicators and get the DataFrame we're after.
#
# Below are some example settings for this tutorial. For clarity, we will first store them in variables, but you can
# always pass them directly as arguments to the `ODAData` class.

# %%
# Select years as (for example) a range. Remember ranges are exclusive of the upper bound.
YEARS = range(1960, 2024)

# Set the base year. We must set this given that we've asked for constant data.
BASE_YEAR = 2022

# Define prices
PRICES = "constant"

# Instantiate the `ODAData` class and store it in a variable called 'oda'
oda = ODAData(years=YEARS,
              prices=PRICES,
              base_year=BASE_YEAR,
              include_names=True)

# %% [markdown]
# ## 3. Load the indicators and get the DataFrame
#
# Then we tell `oda` to load the indicator(s) that are useful for our analysis. For this tutorial, we will use the *"recipient_bilateral_flow_disbursement_gross"*, and *"imputed_multi_flow_disbursement_gross"* indicators
#
# A full list of indicators can be seen by using the `.available_indicators()` method.

# %%
# print available indicators
ODAData().available_indicators()
# Out:
# [
# total_oda_flow_net,
# total_oda_ge,
# total_oda_official_definition,
# total_oda_bilateral_flow_net,
# total_oda_bilateral_ge,
# total_oda_multilateral_flow_net,
# total_oda_multilateral_ge,
# total_oda_flow_gross,
# total_oda_flow_commitments,
# total_oda_grants_flow,
# total_oda_grants_ge,
# total_oda_non_grants_flow,
# total_oda_non_grants_ge,
# total_covid_oda_ge,
# total_covid_oda_flow,
# total_health_covid_oda_ge,
# total_health_covid_oda_flow,
# total_health_covid_oda_ge_linked,
# total_covid_vaccine_donations_oda_ge,
# total_covid_vaccine_donations_oda_flow,
# total_covid_vaccine_donations_oda_ge_linked,
# total_covid_vaccine_donations_domestic_supply_oda_ge,
# total_covid_vaccine_donations_domestic_supply_oda_flow,
# total_covid_vaccine_donations_domestic_supply_oda_ge_linked,
# total_covid_vaccine_donations_dev_purchase_oda_ge,
# total_covid_vaccine_donations_dev_purchase_oda_flow,
# total_covid_vaccine_donations_dev_purchase_oda_ge_linked,
# total_covid_ancillary_oda_ge,
# total_covid_ancillary_oda_flow,
# total_covid_ancillary_oda_ge_linked,
# gni,
# oda_gni_flow,
# oda_gni_ge,
# total_in_donor_students_flow,
# total_in_donor_students_ge,
# total_in_donor_students_ge_linked,
# scholarships_flow,
# scholarships_ge,
# scholarships_ge_linked,
# imputed_students_flow,
# imputed_students_ge,
# imputed_students_linked,
# debt_relief_flow,
# debt_relief_ge,
# idrc_flow,
# idrc_ge,
# idrc_ge_linked,
# eu_core_flow,
# eu_core_ge,
# eu_core_ge_linked,
# one_non_core_oda_flow,
# one_non_core_oda_ge,
# one_non_core_oda_ge_linked,
# one_core_oda_flow,
# one_core_oda_ge,
# one_core_oda_ge_linked,
# total_psi_flow,
# total_psi_ge,
# total_psi_flow_linked,
# institutional_psi_flow,
# institutional_psi_ge,
# institutional_psi_flow_linked,
# instrument_psi_flow,
# instrument_psi_ge,
# instrument_psi_flow_linked,
# recipient_imputed_multi_flow_net,
# recipient_bilateral_flow_net,
# recipient_bilateral_flow_gross,
# recipient_loans_flow_gross,
# recipient_loans_flow_net,
# recipient_interest_received_flow,
# recipient_humanitarian_flow,
# recipient_grants_flow,
# recipient_total_flow_net,
# crs_bilateral_flow_disbursement_gross,
# crs_bilateral_ge,
# crs_bilateral_all_flows_disbursement_gross,
# crs_gender_significant_flow_disbursement_gross,
# crs_gender_principal_flow_disbursement_gross,
# crs_gender_not_targeted_flow_disbursement_gross,
# crs_gender_not_screened_flow_disbursement_gross,
# crs_gender_allocable_flow_disbursement_gross,
# crs_gender_allocable_total_flow_disbursement_gross,
# crs_gender_total_flow_gross,
# crs_bilateral_total_flow_gross_by_purpose,
# multisystem_multilateral_contributions_disbursement_gross,
# multisystem_multilateral_contributions_commitments_gross,
# multilateral_purpose_spending_shares,
# imputed_multi_flow_disbursement_gross,
# total_bi_multi_flow_disbursement_gross,
# crs_climate_allocable_flow_disbursement_gross,
# crs_climate_mitigation_significant_flow_disbursement_gross,
# crs_climate_mitigation_principal_flow_disbursement_gross,
# crs_climate_mitigation_not_targeted_flow_disbursement_gross,
# crs_climate_mitigation_not_screened_flow_disbursement_gross,
# crs_climate_mitigation_total_flow_gross,
# crs_climate_adaptation_significant_flow_disbursement_gross,
# crs_climate_adaptation_principal_flow_disbursement_gross,
# crs_climate_adaptation_not_targeted_flow_disbursement_gross,
# crs_climate_adaptation_not_screened_flow_disbursement_gross,
# crs_climate_adaptation_total_flow_gross,
# crs_climate_mitigation_adaptation_overlap_significant_flow_disbursement_gross
# ]

# %%
# Create a variable with the list of indicators for this analysis.
# The indicator can also be directly passed as an argument in the step below.
indicators = ['crs_bilateral_flow_disbursement_gross',
              'imputed_multi_flow_disbursement_gross']

# Add all the indicators in our `indicators` list
for indicator in indicators:
    oda.load_indicator(indicator)

# Get a DataFrame with all the data.
df = oda.get_data('all')

for col in df.columns:
    print(col)

# # Finally, group the DataFrame rows by year, currency, prices and indicator
df = df.groupby(['year','donor_code', "recipient_code", "indicator", 'purpose_code', 'currency', 'prices'], observed=True,
           dropna=False)['value'].sum(numeric_only=True).reset_index(drop=False)

# show the resulting dataframe
df.sample(10)
# Out:
# INFO [exchange_data.py: load_data:] Data not found, downloading...
# INFO: Data not found, downloading...
# INFO: Downloading DAC1 data. This may take a while...
# INFO: Reading the dac1 schema translation
# INFO: Fetching data from https://sdmx.oecd.org/public/rest/data/OECD.DCD.FSD,DSD_DAC1@DF_DAC1,/.1010+11010..1140+1160...?format=csvfilewithlabels
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/etl/.venv/lib/python3.11/site-packages/pydeflate/get_data/exchange_data.py:189, in ExchangeOECD.load_data(self, **kwargs)
#     188 try:
# --> 189     self._data = pd.read_feather(
#     190         PYDEFLATE_PATHS.data / "pydeflate_dac1.feather"
#     191     )
#     192 except FileNotFoundError:
#
# File ~/etl/.venv/lib/python3.11/site-packages/pandas/io/feather_format.py:120, in read_feather(path, columns, use_threads, storage_options, dtype_backend)
#     118 check_dtype_backend(dtype_backend)
# --> 120 with get_handle(
#     121     path, "rb", storage_options=storage_options, is_text=False
#     122 ) as handles:
#     123     if dtype_backend is lib.no_default and not using_pyarrow_string_dtype():
#
# File ~/etl/.venv/lib/python3.11/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880 else:
#     881     # Binary mode
# --> 882     handle = open(handle, ioargs.mode)
#     883 handles.append(handle)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/parriagadap/etl/snapshots/oecd/2024-08-21/pydeflate_dac1.feather'
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       6 # Add all the indicators in our `indicators` list
#       7 for indicator in indicators:
# ----> 8     oda.load_indicator(indicator)
#      10 # Get a DataFrame with all the data.
#      11 df = oda.get_data('all')
#
# File ~/etl/.venv/lib/python3.11/site-packages/oda_data/classes/oda_data.py:586, in ODAData.load_indicator(self, indicators, **kwargs)
#     584 # Load each indicator
#     585 for single_indicator in indicators:
# --> 586     __load_single_indicator(ind_=single_indicator)
#     588 return self
#
# File ~/etl/.venv/lib/python3.11/site-packages/oda_data/classes/oda_data.py:582, in ODAData.load_indicator.<locals>.__load_single_indicator(ind_)
#     579     self.indicators_data[ind_] = self._build_research_indicator(ind_)
#     581 # Convert the units if necessary
# --> 582 self._convert_units(ind_)
#
# File ~/etl/.venv/lib/python3.11/site-packages/oda_data/classes/oda_data.py:321, in ODAData._convert_units(self, indicator)
#     315     self.indicators_data[indicator] = clean.dac_exchange(
#     316         df=self.indicators_data[indicator],
#     317         target_currency=CURRENCIES[self.currency],
#     318     ).assign(currency=self.currency, prices=self.prices)
#     320 else:
# --> 321     self.indicators_data[indicator] = clean.dac_deflate(
#     322         df=self.indicators_data[indicator],
#     323         base_year=self.base_year,
#     324         target_currency=CURRENCIES[self.currency],
#     325     ).assign(currency=self.currency, prices=self.prices)
#
# File ~/etl/.venv/lib/python3.11/site-packages/pydeflate/deflate/deflate.py:292, in deflate(df, base_year, deflator_source, deflator_method, exchange_source, exchange_method, source_currency, target_currency, id_column, id_type, date_column, source_column, target_column, to_current, method, source, iso_column, source_col, target_col)
#     288 df = _create_id_col(df=df, id_column=id_column, id_type=id_type)
#     290 # ----------------------------- Load deflator data ---------------------------
#     291 deflator = (
# --> 292     Deflator(
#     293         base_year=base_year,
#     294         exchange_obj=ExchangeSources[exchange_source][exchange_method],
#     295         deflator_obj=DeflatorSources[deflator_source](),
#     296         deflator_method=deflator_method,
#     297         source_currency=source_currency,
#     298         target_currency=target_currency,
#     299         to_current=to_current,
#     300     )
#     301     .get_deflator()
#     302     .rename(columns={"iso_code": "id_", "year": date_column})
#     303 )
#     305 # ----------------------------- Deflate ---------------------------
#     306 # Merge the original data with the deflator DataFrame
#     307 df = df.merge(
#     308     deflator,
#     309     on=["id_", date_column],
#     310     how="left",
#     311     suffixes=("", "_"),
#     312 )
#
# File <string>:13, in __init__(self, base_year, exchange_obj, deflator_obj, deflator_method, source_currency, target_currency, to_current, _xe_df, _xe_deflator_df, _price_deflator_df)
#
# File ~/etl/.venv/lib/python3.11/site-packages/pydeflate/deflate/deflator.py:42, in Deflator.__post_init__(self)
#      40 def __post_init__(self):
#      41     # Exchange deflator DataFrame, including any currency conversion
# ---> 42     self._xe_deflator_df = self.exchange_obj.exchange_deflator(
#      43         source_iso=self.source_currency,
#      44         target_iso=self.target_currency,
#      45         base_year=self.base_year,
#      46     )
#      48     # Price deflator DataFrame
#      49     self._price_deflator_df = self.deflator_obj.get_deflator(
#      50         base_year=self.base_year, method=self.deflator_method
#      51     )
#
# File ~/etl/.venv/lib/python3.11/site-packages/pydeflate/get_data/exchange_data.py:118, in Exchange.exchange_deflator(self, source_iso, target_iso, base_year)
#     104 """Get an exchange rate deflator for a given ISO
#     105
#     106 Args:
#    (...)
#     114
#     115 """
#     116 # Get exchange data based on the source currency. If LCU set to None
#     117 source_xe = (
# --> 118     self.exchange_rate(currency_iso=source_iso)
#     119     if source_iso != "LCU"
#     120     else self.exchange_rate(currency_iso="USA").assign(value=1)
#     121 )
#     123 # Get exchange data based on the target currency. If LCU set to None
#     124 target_xe = (
#     125     self.exchange_rate(currency_iso=target_iso)
#     126     if target_iso != "LCU"
#     127     else self.exchange_rate(currency_iso="USA").assign(value=1)
#     128 )
#
# File ~/etl/.venv/lib/python3.11/site-packages/pydeflate/get_data/exchange_data.py:85, in Exchange.exchange_rate(self, currency_iso)
#      75 """Get an exchange rate for a given ISO
#      76
#      77 Args:
#    (...)
#      81     A dataframe with the exchange rate for the specified currency.
#      82 """
#      84 # get usd exchange rates
# ---> 85 d_ = self.usd_exchange_rate()
#      87 # filter the exchange rate of the chosen currency
#      88 target_iso = d_.query(f"iso_code == '{currency_iso}'")
#
# File ~/etl/.venv/lib/python3.11/site-packages/pydeflate/get_data/exchange_data.py:211, in ExchangeOECD.usd_exchange_rate(self, direction)
#     209 # If data is not loaded, load it
#     210 if self._data is None:
# --> 211     self.load_data()
#     213 # Filter the data to only include the required columns, rename the value column.
#     214 d_ = self._data[["iso_code", "year", "exchange"]].rename(
#     215     columns={"exchange": "value"}
#     216 )
#
# File ~/etl/.venv/lib/python3.11/site-packages/pydeflate/get_data/exchange_data.py:194, in ExchangeOECD.load_data(self, **kwargs)
#     192 except FileNotFoundError:
#     193     logger.info("Data not found, downloading...")
# --> 194     self.update()
#     195     self.load_data()
#     196     return
#
# File ~/etl/.venv/lib/python3.11/site-packages/pydeflate/get_data/exchange_data.py:175, in ExchangeOECD.update(**kwargs)
#     172 """Update the DAC1 data, which is the source for the OECD exchange rates."""
#     173 from pydeflate.get_data import oecd_data
# --> 175 oecd_data.update_dac1()
#
# File ~/etl/.venv/lib/python3.11/site-packages/pydeflate/get_data/oecd_data.py:67, in update_dac1()
#      64 """Update dac1 data from OECD site and save as feather"""
#      66 # Use oda_reader to get the data
# ---> 67 df = download_dac1(
#      68     filters={"measure": ["1010", "11010"], "flow_type": ["1140", "1160"]}
#      69 )
#      71 # Clean the data
#      72 df = df.pipe(_clean_dac1)
#
# File ~/etl/.venv/lib/python3.11/site-packages/oda_reader/dac1.py:35, in download_dac1(start_year, end_year, filters, pre_process, dotstat_codes)
#      32 # Inform download is about to start
#      33 logger.info("Downloading DAC1 data. This may take a while...")
# ---> 35 df = download(
#      36     version="dac1",
#      37     dataflow_id=DATAFLOW_ID,
#      38     start_year=start_year,
#      39     end_year=end_year,
#      40     filters=filters,
#      41     pre_process=pre_process,
#      42     dotstat_codes=dotstat_codes,
#      43 )
#      45 return df
#
# File ~/etl/.venv/lib/python3.11/site-packages/oda_reader/download/download_tools.py:75, in download(version, dataflow_id, start_year, end_year, filters, pre_process, dotstat_codes)
#      72 url = qb.set_time_period(start=start_year, end=end_year).build_query()
#      74 # Get the dataframe
# ---> 75 df = api_response_to_df(url=url, read_csv_options=df_options)
#      77 # Preprocess the data
#      78 if pre_process:
#
# File ~/etl/.venv/lib/python3.11/site-packages/oda_reader/common.py:89, in api_response_to_df(url, read_csv_options, compressed)
#      86     return pd.read_csv(url, **read_csv_options)
#      88 # Fetch the data from the API with compression headers
# ---> 89 response = get_data_from_api(url=url, compressed=compressed)
#      91 # Convert the content to stringIO
#      92 data = text_to_stringIO(response)
#
# File ~/etl/.venv/lib/python3.11/site-packages/oda_reader/common.py:61, in get_data_from_api(url, compressed)
#      58     raise ConnectionError("No data found for the selected parameters.")
#      60 # Ensure the request was successful
# ---> 61 response.raise_for_status()
#      63 return response
#
# File ~/etl/.venv/lib/python3.11/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://sdmx.oecd.org/public/rest/data/OECD.DCD.FSD,DSD_DAC1@DF_DAC1,/.1010+11010..1140+1160...?format=csvfilewithlabels

# %% [markdown]
# ## 4. Optionally export DataFrame as CSV
#
# Finally, we can export the DataFrame as a CSV if required.

# %%
df.to_csv("/Users/parriagadap/etl/snapshots/oecd/2024-08-21/oda_by_sectors_oda.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df.to_csv(r'../tutorials/output/oda_by_sectors_oda.csv', index=False)
#
# File ~/etl/.venv/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/etl/.venv/lib/python3.11/site-packages/pandas/core/generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File ~/etl/.venv/lib/python3.11/site-packages/pandas/io/formats/format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File ~/etl/.venv/lib/python3.11/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File ~/etl/.venv/lib/python3.11/site-packages/pandas/io/common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File ~/etl/.venv/lib/python3.11/site-packages/pandas/io/common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '../tutorials/output'
